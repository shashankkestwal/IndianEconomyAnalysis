# %% [markdown]
# # Data Analysis and Visualisation of Indian Economy
# <hr>
#
# #### Team Information : <br><br> 1. Harsh Bamotra (AC-1216) <br> 2. Shashank Kestwal (AC-1245)
#
# Teacher       : **Prof. Sharanjit Kaur** <br>
# Course        : **BSc. (H) Computer Science** <br>
# Semester/Year : **5th / 3rd Year** <br>
# College       : **Acharya Narendra Dev College** <br>

# %% [markdown]
# **Importing required modules**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Reading data files**

# %% [markdown]
# reading data from the csv file clearing the data

# %%
sgdp = pd.read_csv("SGDP.csv", header=0)
sgdp.shape
# Out:
# (11, 36)

# %% [markdown]
# **Getting information about the dataset**

# %%
sgdp.shape
# Out:
# (11, 36)

# %%
sgdp.columns
# Out:
# Index(['Items  Description', 'Duration', 'Andhra Pradesh ',
#        'Arunachal Pradesh', 'Assam', 'Bihar', 'Chhattisgarh', 'Goa', 'Gujarat',
#        'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir', 'Jharkhand',
#        'Karnataka', 'Kerala', 'Madhya Pradesh', 'Maharashtra', 'Manipur',
#        'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Punjab', 'Rajasthan',
#        'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura', 'Uttar Pradesh',
#        'Uttarakhand', 'West Bengal1', 'Andaman & Nicobar Islands',
#        'Chandigarh', 'Delhi', 'Puducherry', 'All_India GDP'],
#       dtype='object')

# %%
sgdp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 36 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Items  Description         11 non-null     object
#  1   Duration                   11 non-null     object
#  2   Andhra Pradesh             11 non-null     float64
#  3   Arunachal Pradesh          9 non-null      float64
#  4   Assam                      9 non-null      float64
#  5   Bihar                      9 non-null      float64
#  6   Chhattisgarh               11 non-null     float64
#  7   Goa                        9 non-null      float64
#  8   Gujarat                    9 non-null      float64
#  9   Haryana                    11 non-null     float64
#  10  Himachal Pradesh           7 non-null      float64
#  11  Jammu & Kashmir            9 non-null      float64
#  12  Jharkhand                  9 non-null      float64
#  13  Karnataka                  9 non-null      float64
#  14  Kerala                     9 non-null      float64
#  15  Madhya Pradesh             11 non-null     float64
#  16  Maharashtra                7 non-null      float64
#  17  Manipur                    7 non-null      float64
#  18  Meghalaya                  11 non-null     float64
#  19  Mizoram                    7 non-null      float64
#  20  Nagaland                   7 non-null      float64
#  21  Odisha                     11 non-null     float64
#  22  Punjab                     7 non-null      float64
#  23  Rajasthan                  7 non-null      float64
#  24  Sikkim                     9 non-null      float64
#  25  Tamil Nadu                 11 non-null     float64
#  26  Telangana                  11 non-null     float64
#  27  Tripura                    7 non-null      float64
#  28  Uttar Pradesh              9 non-null      float64
#  29  Uttarakhand                9 non-null      float64
#  30  West Bengal1               0 non-null      float64
#  31  Andaman & Nicobar Islands  7 non-null      float64
#  32  Chandigarh                 9 non-null      float64
#  33  Delhi                      11 non-null     float64
#  34  Puducherry                 11 non-null     float64
#  35  All_India GDP              11 non-null     float64
# dtypes: float64(34), object(2)
# memory usage: 3.2+ KB

# %%
sgdp.describe()
# Out:
#        Andhra Pradesh   Arunachal Pradesh          Assam          Bihar  \
# count        11.000000           9.000000       9.000000       9.000000
# mean     280986.561818        8201.516667  100018.167778  181565.673333
# std      282573.532407        8073.276061   97589.497456  178700.497677
# min           8.430000          12.070000       9.560000      10.590000
# 25%          14.025000          14.790000      13.190000      14.250000
# 50%      379402.000000       11063.000000  143175.000000  247144.000000
# 75%      495370.000000       14602.000000  177745.000000  317101.000000
# max      699307.000000       18784.000000  224234.000000  413503.000000
#
#         Chhattisgarh           Goa        Gujarat        Haryana  \
# count      11.000000      9.000000       9.000000      11.000000
# mean   120748.879091  22450.120000  448568.674444  228667.271818
# std    120928.480448  21443.429799  438025.627165  228195.895576
# min        10.980000    -10.020000      10.820000       9.180000
# 25%        12.995000     10.750000      11.470000      14.135000
# 50%    158074.000000  35921.000000  615606.000000  297539.000000
# 75%    220836.000000  40633.000000  807623.000000  419062.000000
# max    290140.000000  45002.000000  994316.000000  547396.000000
#
#        Himachal Pradesh  Jammu & Kashmir  ...      Telangana       Tripura  \
# count          7.000000         9.000000  ...      11.000000      7.000000
# mean       50673.064286     53343.001111  ...  268570.787273  13739.691429
# std        48384.121107     51712.668467  ...  268734.549079  13240.797263
# min           10.140000         4.700000  ...      11.700000     12.780000
# 25%           14.155000        11.310000  ...      12.840000     17.030000
# 50%        72720.000000     78254.000000  ...  359433.000000  19208.000000
# 75%        88792.000000     95893.000000  ...  481682.000000  23628.000000
# max       104369.000000    118387.000000  ...  654294.000000  29667.000000
#
#        Uttar Pradesh    Uttarakhand  West Bengal1  Andaman & Nicobar Islands  \
# count   9.000000e+00       9.000000           0.0                   7.000000
# mean    5.209237e+05   82588.947778           NaN                2759.814286
# std     5.087288e+05   80553.858327           NaN                2627.016700
# min     1.051000e+01       8.120000           NaN                  10.890000
# 25%     1.365000e+01      13.650000           NaN                  13.905000
# 50%     7.240490e+05  115523.000000           NaN                3979.000000
# 75%     9.441460e+05  149817.000000           NaN                4790.000000
# max     1.153795e+06  184091.000000           NaN                5721.000000
#
#          Chandigarh          Delhi    Puducherry  All_India GDP
# count      9.000000      11.000000     11.000000   1.100000e+01
# mean   13707.002222  258693.004545  12527.435455   6.479952e+06
# std    13399.003286  258176.516280  12445.889343   6.433000e+06
# min        8.840000      10.960000     10.140000   9.990000e+00
# 25%       14.710000      13.095000     11.815000   1.224500e+01
# 50%    18768.000000  343767.000000  16818.000000   8.736039e+06
# 75%    24787.000000  468103.500000  22979.500000   1.183519e+07
# max    30304.000000  622385.000000  29557.000000   1.525103e+07
#
# [8 rows x 34 columns]

# %%
sgdp.describe()
# Out:
#        Andhra Pradesh   Arunachal Pradesh          Assam          Bihar  \
# count        11.000000           9.000000       9.000000       9.000000
# mean     280986.561818        8201.516667  100018.167778  181565.673333
# std      282573.532407        8073.276061   97589.497456  178700.497677
# min           8.430000          12.070000       9.560000      10.590000
# 25%          14.025000          14.790000      13.190000      14.250000
# 50%      379402.000000       11063.000000  143175.000000  247144.000000
# 75%      495370.000000       14602.000000  177745.000000  317101.000000
# max      699307.000000       18784.000000  224234.000000  413503.000000
#
#         Chhattisgarh           Goa        Gujarat        Haryana  \
# count      11.000000      9.000000       9.000000      11.000000
# mean   120748.879091  22450.120000  448568.674444  228667.271818
# std    120928.480448  21443.429799  438025.627165  228195.895576
# min        10.980000    -10.020000      10.820000       9.180000
# 25%        12.995000     10.750000      11.470000      14.135000
# 50%    158074.000000  35921.000000  615606.000000  297539.000000
# 75%    220836.000000  40633.000000  807623.000000  419062.000000
# max    290140.000000  45002.000000  994316.000000  547396.000000
#
#        Himachal Pradesh  Jammu & Kashmir  ...      Telangana       Tripura  \
# count          7.000000         9.000000  ...      11.000000      7.000000
# mean       50673.064286     53343.001111  ...  268570.787273  13739.691429
# std        48384.121107     51712.668467  ...  268734.549079  13240.797263
# min           10.140000         4.700000  ...      11.700000     12.780000
# 25%           14.155000        11.310000  ...      12.840000     17.030000
# 50%        72720.000000     78254.000000  ...  359433.000000  19208.000000
# 75%        88792.000000     95893.000000  ...  481682.000000  23628.000000
# max       104369.000000    118387.000000  ...  654294.000000  29667.000000
#
#        Uttar Pradesh    Uttarakhand  West Bengal1  Andaman & Nicobar Islands  \
# count   9.000000e+00       9.000000           0.0                   7.000000
# mean    5.209237e+05   82588.947778           NaN                2759.814286
# std     5.087288e+05   80553.858327           NaN                2627.016700
# min     1.051000e+01       8.120000           NaN                  10.890000
# 25%     1.365000e+01      13.650000           NaN                  13.905000
# 50%     7.240490e+05  115523.000000           NaN                3979.000000
# 75%     9.441460e+05  149817.000000           NaN                4790.000000
# max     1.153795e+06  184091.000000           NaN                5721.000000
#
#          Chandigarh          Delhi    Puducherry  All_India GDP
# count      9.000000      11.000000     11.000000   1.100000e+01
# mean   13707.002222  258693.004545  12527.435455   6.479952e+06
# std    13399.003286  258176.516280  12445.889343   6.433000e+06
# min        8.840000      10.960000     10.140000   9.990000e+00
# 25%       14.710000      13.095000     11.815000   1.224500e+01
# 50%    18768.000000  343767.000000  16818.000000   8.736039e+06
# 75%    24787.000000  468103.500000  22979.500000   1.183519e+07
# max    30304.000000  622385.000000  29557.000000   1.525103e+07
#
# [8 rows x 34 columns]

# %% [markdown]
# ## Data cleaning and pre-processing
# -----------------------------------------------
# ### Handling missing values

# %% [markdown]
# *Checking for missing or Nan values*

# %%
sgdp.isna().sum()
# Out:
# Items  Description            0
# Duration                      0
# Andhra Pradesh                0
# Arunachal Pradesh             2
# Assam                         2
# Bihar                         2
# Chhattisgarh                  0
# Goa                           2
# Gujarat                       2
# Haryana                       0
# Himachal Pradesh              4
# Jammu & Kashmir               2
# Jharkhand                     2
# Karnataka                     2
# Kerala                        2
# Madhya Pradesh                0
# Maharashtra                   4
# Manipur                       4
# Meghalaya                     0
# Mizoram                       4
# Nagaland                      4
# Odisha                        0
# Punjab                        4
# Rajasthan                     4
# Sikkim                        2
# Tamil Nadu                    0
# Telangana                     0
# Tripura                       4
# Uttar Pradesh                 2
# Uttarakhand                   2
# West Bengal1                 11
# Andaman & Nicobar Islands     4
# Chandigarh                    2
# Delhi                         0
# Puducherry                    0
# All_India GDP                 0
# dtype: int64

# %% [markdown]
# *Missing value percentage in the dataset*

# %%
sgdp.isna().sum()/len(sgdp)*100
# Out:
# Items  Description             0.000000
# Duration                       0.000000
# Andhra Pradesh                 0.000000
# Arunachal Pradesh             18.181818
# Assam                         18.181818
# Bihar                         18.181818
# Chhattisgarh                   0.000000
# Goa                           18.181818
# Gujarat                       18.181818
# Haryana                        0.000000
# Himachal Pradesh              36.363636
# Jammu & Kashmir               18.181818
# Jharkhand                     18.181818
# Karnataka                     18.181818
# Kerala                        18.181818
# Madhya Pradesh                 0.000000
# Maharashtra                   36.363636
# Manipur                       36.363636
# Meghalaya                      0.000000
# Mizoram                       36.363636
# Nagaland                      36.363636
# Odisha                         0.000000
# Punjab                        36.363636
# Rajasthan                     36.363636
# Sikkim                        18.181818
# Tamil Nadu                     0.000000
# Telangana                      0.000000
# Tripura                       36.363636
# Uttar Pradesh                 18.181818
# Uttarakhand                   18.181818
# West Bengal1                 100.000000
# Andaman & Nicobar Islands     36.363636
# Chandigarh                    18.181818
# Delhi                          0.000000
# Puducherry                     0.000000
# All_India GDP                  0.000000
# dtype: float64

# %% [markdown]
# *Dropping attribute with 50*% missing or Nan values from the dataset*

# %%
# total of 11 rows so each state must contain more than 66% of the data for furthur details
half = len(sgdp) / 2 
x = sgdp.isna().sum() > half
drop_indexes = sgdp.columns[x]
# dropping columns from the dataframe 
sgdp.drop(drop_indexes, axis=1, inplace=True)
sgdp.shape
# Out:
# (11, 35)

# %% [markdown]
# #distingusing dataset on the basis of total gdp and total percent growth

# %%
total_gdp = sgdp.loc[:5]
total_gdp
percent_growth_gdp =  sgdp.iloc[6:]
percent_growth_gdp.index = range(0, 5)
percent_growth_gdp
# Out:
#               Items  Description Duration  Andhra Pradesh   Arunachal Pradesh  \
# 0  (% Growth over previous year)  2012-13             8.43              13.41
# 1  (% Growth over previous year)  2013-14            12.85              16.38
# 2  (% Growth over previous year)  2014-15            13.40              14.79
# 3  (% Growth over previous year)  2015-16            15.85              12.07
# 4  (% Growth over previous year)  2016-17            14.65                NaN
#
#    Assam  Bihar  Chhattisgarh    Goa  Gujarat  Haryana  ...  Tamil Nadu  \
# 0   9.56  14.25         12.30 -10.02    17.69    16.63  ...       13.84
# 1  13.31  12.30         16.44  -5.77    11.47    15.45  ...       13.51
# 2  11.45  17.92         13.69  13.12    10.82     9.18  ...       12.51
# 3  13.19  10.59         10.98  10.75    11.09    10.91  ...       10.99
# 4    NaN    NaN         11.26    NaN      NaN    12.82  ...       10.40
#
#    Telangana  Tripura  Uttar Pradesh  Uttarakhand  Andaman & Nicobar Islands  \
# 0      11.70    12.78          13.65        14.12                      11.13
# 1      12.63    18.14          14.73        13.64                      16.68
# 2      13.05    15.92          10.51         8.12                      10.89
# 3      12.61      NaN          10.58        13.65                        NaN
# 4      13.67      NaN            NaN          NaN                        NaN
#
#    Chandigarh  Delhi  Puducherry  All_India GDP
# 0       15.14  13.81       12.23          13.86
# 1       14.71  13.43       15.87          12.97
# 2       12.33  10.96       10.14          10.65
# 3        8.84  12.09       10.15           9.99
# 4         NaN  12.76       11.40          11.52
#
# [5 rows x 35 columns]

# %% [markdown]
# ### Data Transformation

# %% [markdown]
# *Checking for duplicate data*

# %%
sgdp.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# dtype: bool

# %% [markdown]
# *No duplicate values present in the dataset*

# %% [markdown]
# ## Data analysis and visualization

# %%
sgdp.iloc[6:,2:35].mean().round(2).sort_values().plot.bar()
# Out:
# <AxesSubplot: >

# %% [markdown]
# compairing the GDP growth rates of my home state(Uttarakhand, Himanchal Pradesh) with that of INDIA

# %%
mean = sgdp[6:]
home_state = mean[['Uttarakhand', 'All_India GDP']]
comapred_states = home_state.sum()/ home_state.count()
comapred_states.plot(kind='bar',stacked=True, colormap = 'Dark2')
plt.title("Avg. % Growth of Home State vs National Avg. for Duration 2013-14, 2014-15 and 2015-16", fontweight = 'bold')
plt.xlabel("Home State Vs National Average", fontweight = 'bold')
plt.ylabel("% growth rate", fontweight = 'bold')
# Out:
# Text(0, 0.5, '% growth rate')

# %%
#comparison for uttarakhand
home_state = mean[['Uttarakhand', 'All_India GDP']]
comapred_states = home_state.sum()/ home_state.count()
comapred_states.plot(kind='bar',stacked=True, colormap = 'Dark2')
plt.title("Avg. % Growth of Home State vs National Avg. for Duration 2013-14, 2014-15 and 2015-16", fontweight = 'bold')
plt.xlabel("Home State Vs National Average", fontweight = 'bold')
plt.ylabel("% growth rate", fontweight = 'bold')
# Out:
# Text(0, 0.5, '% growth rate')

# %%
#comparison for uttarakhand

home_state = mean[['Himachal Pradesh', 'All_India GDP']]
comapred_states = home_state.sum()/ home_state.count()
comapred_states.plot(kind='bar',stacked=True, colormap = 'Dark2')
plt.title("Avg. % Growth of Home State vs National Avg. for Duration 2013-14, 2014-15 and 2015-16", fontweight = 'bold')
plt.xlabel("Home State Vs National Average", fontweight = 'bold')
plt.ylabel("% growth rate", fontweight = 'bold')
# Out:
# Text(0, 0.5, '% growth rate')

# %%
total_gdp
# Out:
#                    Items  Description Duration  Andhra Pradesh   \
# 0  GSDP - CURRENT PRICES (` in Crore)  2011-12         379402.0
# 1  GSDP - CURRENT PRICES (` in Crore)  2012-13         411404.0
# 2  GSDP - CURRENT PRICES (` in Crore)  2013-14         464272.0
# 3  GSDP - CURRENT PRICES (` in Crore)  2014-15         526468.0
# 4  GSDP - CURRENT PRICES (` in Crore)  2015-16         609934.0
# 5  GSDP - CURRENT PRICES (` in Crore)  2016-17         699307.0
#
#    Arunachal Pradesh     Assam     Bihar  Chhattisgarh      Goa   Gujarat  \
# 0            11063.0  143175.0  247144.0      158074.0  42367.0  615606.0
# 1            12547.0  156864.0  282368.0      177511.0  38120.0  724495.0
# 2            14602.0  177745.0  317101.0      206690.0  35921.0  807623.0
# 3            16761.0  198098.0  373920.0      234982.0  40633.0  895027.0
# 4            18784.0  224234.0  413503.0      260776.0  45002.0  994316.0
# 5                NaN       NaN       NaN      290140.0      NaN       NaN
#
#     Haryana  ...  Tamil Nadu  Telangana  Tripura  Uttar Pradesh  Uttarakhand  \
# 0  297539.0  ...    751485.0   359433.0  19208.0       724049.0     115523.0
# 1  347032.0  ...    855481.0   401493.0  21663.0       822903.0     131835.0
# 2  400662.0  ...    971090.0   452186.0  25593.0       944146.0     149817.0
# 3  437462.0  ...   1092564.0   511178.0  29667.0      1043371.0     161985.0
# 4  485184.0  ...   1212668.0   575631.0      NaN      1153795.0     184091.0
# 5  547396.0  ...   1338766.0   654294.0      NaN            NaN          NaN
#
#    Andaman & Nicobar Islands  Chandigarh     Delhi  Puducherry  All_India GDP
# 0                     3979.0     18768.0  343767.0     16818.0      8736039.0
# 1                     4421.0     21609.0  391238.0     18875.0      9946636.0
# 2                     5159.0     24787.0  443783.0     21870.0     11236635.0
# 3                     5721.0     27844.0  492424.0     24089.0     12433749.0
# 4                        NaN     30304.0  551963.0     26533.0     13675331.0
# 5                        NaN         NaN  622385.0     29557.0     15251028.0
#
# [6 rows x 35 columns]

# %% [markdown]
# forward filling the GDP data from the presious year value of current data not found.

# %%
total_gdp.ffill(inplace=True)
# Out:
# /tmp/ipykernel_162035/240387066.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   total_gdp.ffill(inplace=True)

# %% [markdown]
# plotting the GDP of all states in year 2016- 2017

# %%
gpd_2017 = total_gdp.loc[5][2:]
gpd_2017.drop(labels='All_India GDP', inplace=True)
gpd_2017.sort_values(inplace=True)
gpd_2017.plot(kind='bar',stacked=True)
# Out:
# <AxesSubplot: >

# %%
total_gdp = total_gdp.T
total_gdp.columns = total_gdp.loc['Duration']

# %%
total_gdp.iloc[-1].index[-1]
total_gdp
# Out:
# Duration                                              2011-12  \
# Items  Description         GSDP - CURRENT PRICES (` in Crore)
# Duration                                              2011-12
# Andhra Pradesh                                       379402.0
# Arunachal Pradesh                                     11063.0
# Assam                                                143175.0
# Bihar                                                247144.0
# Chhattisgarh                                         158074.0
# Goa                                                   42367.0
# Gujarat                                              615606.0
# Haryana                                              297539.0
# Himachal Pradesh                                      72720.0
# Jammu & Kashmir                                       78254.0
# Jharkhand                                            150918.0
# Karnataka                                            603778.0
# Kerala                                               364048.0
# Madhya Pradesh                                       315561.0
# Maharashtra                                         1272967.0
# Manipur                                               12915.0
# Meghalaya                                             19918.0
# Mizoram                                                7259.0
# Nagaland                                              11839.0
# Odisha                                               227872.0
# Punjab                                               266628.0
# Rajasthan                                            436465.0
# Sikkim                                                11165.0
# Tamil Nadu                                           751485.0
# Telangana                                            359433.0
# Tripura                                               19208.0
# Uttar Pradesh                                        724049.0
# Uttarakhand                                          115523.0
# Andaman & Nicobar Islands                              3979.0
# Chandigarh                                            18768.0
# Delhi                                                343767.0
# Puducherry                                            16818.0
# All_India GDP                                       8736039.0
#
# Duration                                              2012-13  \
# Items  Description         GSDP - CURRENT PRICES (` in Crore)
# Duration                                              2012-13
# Andhra Pradesh                                       411404.0
# Arunachal Pradesh                                     12547.0
# Assam                                                156864.0
# Bihar                                                282368.0
# Chhattisgarh                                         177511.0
# Goa                                                   38120.0
# Gujarat                                              724495.0
# Haryana                                              347032.0
# Himachal Pradesh                                      82820.0
# Jammu & Kashmir                                       87105.0
# Jharkhand                                            174724.0
# Karnataka                                            691700.0
# Kerala                                               412313.0
# Madhya Pradesh                                       380924.0
# Maharashtra                                         1448466.0
# Manipur                                               13748.0
# Meghalaya                                             21872.0
# Mizoram                                                8362.0
# Nagaland                                              13619.0
# Odisha                                               258275.0
# Punjab                                               297734.0
# Rajasthan                                            494004.0
# Sikkim                                                12338.0
# Tamil Nadu                                           855481.0
# Telangana                                            401493.0
# Tripura                                               21663.0
# Uttar Pradesh                                        822903.0
# Uttarakhand                                          131835.0
# Andaman & Nicobar Islands                              4421.0
# Chandigarh                                            21609.0
# Delhi                                                391238.0
# Puducherry                                            18875.0
# All_India GDP                                       9946636.0
#
# Duration                                              2013-14  \
# Items  Description         GSDP - CURRENT PRICES (` in Crore)
# Duration                                              2013-14
# Andhra Pradesh                                       464272.0
# Arunachal Pradesh                                     14602.0
# Assam                                                177745.0
# Bihar                                                317101.0
# Chhattisgarh                                         206690.0
# Goa                                                   35921.0
# Gujarat                                              807623.0
# Haryana                                              400662.0
# Himachal Pradesh                                      94764.0
# Jammu & Kashmir                                       95893.0
# Jharkhand                                            188567.0
# Karnataka                                            817886.0
# Kerala                                               465041.0
# Madhya Pradesh                                       437737.0
# Maharashtra                                         1647506.0
# Manipur                                               16198.0
# Meghalaya                                             22938.0
# Mizoram                                               10293.0
# Nagaland                                              16612.0
# Odisha                                               291709.0
# Punjab                                               334714.0
# Rajasthan                                            549701.0
# Sikkim                                                13862.0
# Tamil Nadu                                           971090.0
# Telangana                                            452186.0
# Tripura                                               25593.0
# Uttar Pradesh                                        944146.0
# Uttarakhand                                          149817.0
# Andaman & Nicobar Islands                              5159.0
# Chandigarh                                            24787.0
# Delhi                                                443783.0
# Puducherry                                            21870.0
# All_India GDP                                      11236635.0
#
# Duration                                              2014-15  \
# Items  Description         GSDP - CURRENT PRICES (` in Crore)
# Duration                                              2014-15
# Andhra Pradesh                                       526468.0
# Arunachal Pradesh                                     16761.0
# Assam                                                198098.0
# Bihar                                                373920.0
# Chhattisgarh                                         234982.0
# Goa                                                   40633.0
# Gujarat                                              895027.0
# Haryana                                              437462.0
# Himachal Pradesh                                     104369.0
# Jammu & Kashmir                                      100404.0
# Jharkhand                                            217107.0
# Karnataka                                            921788.0
# Kerala                                               526002.0
# Madhya Pradesh                                       481982.0
# Maharashtra                                         1792122.0
# Manipur                                               18043.0
# Meghalaya                                             24408.0
# Mizoram                                               11559.0
# Nagaland                                              18414.0
# Odisha                                               321971.0
# Punjab                                               368011.0
# Rajasthan                                            612194.0
# Sikkim                                                15209.0
# Tamil Nadu                                          1092564.0
# Telangana                                            511178.0
# Tripura                                               29667.0
# Uttar Pradesh                                       1043371.0
# Uttarakhand                                          161985.0
# Andaman & Nicobar Islands                              5721.0
# Chandigarh                                            27844.0
# Delhi                                                492424.0
# Puducherry                                            24089.0
# All_India GDP                                      12433749.0
#
# Duration                                              2015-16  \
# Items  Description         GSDP - CURRENT PRICES (` in Crore)
# Duration                                              2015-16
# Andhra Pradesh                                       609934.0
# Arunachal Pradesh                                     18784.0
# Assam                                                224234.0
# Bihar                                                413503.0
# Chhattisgarh                                         260776.0
# Goa                                                   45002.0
# Gujarat                                              994316.0
# Haryana                                              485184.0
# Himachal Pradesh                                     104369.0
# Jammu & Kashmir                                      118387.0
# Jharkhand                                            241955.0
# Karnataka                                           1027068.0
# Kerala                                               588337.0
# Madhya Pradesh                                       543975.0
# Maharashtra                                         1792122.0
# Manipur                                               18043.0
# Meghalaya                                             26745.0
# Mizoram                                               11559.0
# Nagaland                                              18414.0
# Odisha                                               341887.0
# Punjab                                               368011.0
# Rajasthan                                            612194.0
# Sikkim                                                16637.0
# Tamil Nadu                                          1212668.0
# Telangana                                            575631.0
# Tripura                                               29667.0
# Uttar Pradesh                                       1153795.0
# Uttarakhand                                          184091.0
# Andaman & Nicobar Islands                              5721.0
# Chandigarh                                            30304.0
# Delhi                                                551963.0
# Puducherry                                            26533.0
# All_India GDP                                      13675331.0
#
# Duration                                              2016-17
# Items  Description         GSDP - CURRENT PRICES (` in Crore)
# Duration                                              2016-17
# Andhra Pradesh                                       699307.0
# Arunachal Pradesh                                     18784.0
# Assam                                                224234.0
# Bihar                                                413503.0
# Chhattisgarh                                         290140.0
# Goa                                                   45002.0
# Gujarat                                              994316.0
# Haryana                                              547396.0
# Himachal Pradesh                                     104369.0
# Jammu & Kashmir                                      118387.0
# Jharkhand                                            241955.0
# Karnataka                                           1027068.0
# Kerala                                               588337.0
# Madhya Pradesh                                       640484.0
# Maharashtra                                         1792122.0
# Manipur                                               18043.0
# Meghalaya                                             29567.0
# Mizoram                                               11559.0
# Nagaland                                              18414.0
# Odisha                                               378991.0
# Punjab                                               368011.0
# Rajasthan                                            612194.0
# Sikkim                                                16637.0
# Tamil Nadu                                          1338766.0
# Telangana                                            654294.0
# Tripura                                               29667.0
# Uttar Pradesh                                       1153795.0
# Uttarakhand                                          184091.0
# Andaman & Nicobar Islands                              5721.0
# Chandigarh                                            30304.0
# Delhi                                                622385.0
# Puducherry                                            29557.0
# All_India GDP                                      15251028.0

# %% [markdown]
# *plotting the graph for top 5 and bottom 5 performing states in India*

# %%
top_5_states = gpd_2017.tail(5)
bottom_5_states = gpd_2017.head(5)

# %%
top_5_states.plot(kind='bar', colormap = 'Dark2')
plt.title("Total GDP of top 5 States for 2016-17", fontweight = 'bold')
plt.ylabel("Total GDP (in cr)",fontweight = 'bold')
plt.xlabel("States",fontweight = 'bold')
# Out:
# Text(0.5, 0, 'States')

# %%
bottom_5_states.plot(kind='bar', colormap = 'Dark2')
plt.title("Total GDP of top 5 States for 2016-17", fontweight = 'bold')
plt.ylabel("Total GDP (in cr)",fontweight = 'bold')
plt.xlabel("States",fontweight = 'bold')
# Out:
# Text(0.5, 0, 'States')
